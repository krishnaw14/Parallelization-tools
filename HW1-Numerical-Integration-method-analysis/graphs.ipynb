# %%
from numpy import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
N=[]
for i in range(1,10):
    N.append(i)

# %%
N
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
ts=[]
t2=[]
t4=[]
t6=[]
t8=[]

# %%
ts=[0.0000206
,0.0000226
,0.0000718
,0.0004838
,0.0045426=
,0.0444816
,0.3889052
,3.6117362
,35.0028296]

t2=[0.000201400
,0.000166
,0.000203600
,0.000581200
,0.003813200
,0.037484200
,0.334725200
,3.172518000
,30.820954200]

t4=[0.000252400
,0.000248600
,0.0002904
,0.000551600
,0.003020400
,0.0323844
,0.249208200
,2.359315200
,23.437089400]

t6=[0.000409600
,0.000431800
,0.000408400
,0.000617800
,0.002802200
,0.027938000
,0.210087600
,1.880160800
,18.339058800]

t8=[0.000378200
,0.000387400
,0.0003998
,0.000657200
,0.002900000
,0.027710000
,0.184950800
,1.584643400
,15.395976400]

# %%
plt.plot(N, ts)
plt.plot(N, t2)
plt.plot(N, t4)
plt.plot(N, t6)
plt.plot(N, t8)
plt.legend(["Serial", "2 threads", "4 threads", "6 threads", "8 threads"])
plt.ylabel("Execution time")
plt.xlabel("log(N)")
plt.title("Variation of total time \n with log of No. of sampling points")
plt.savefig("/Users/krishna/Desktop/montecarlo_log.png")

# %%
tps=[0.000007600
,0.000008800
,0.000009800
,0.000010800
,0.000016600
,0.000025400
,0.000093800
,0.000173800
,0.000839600
,0.001627800
,0.014985400
,0.1519874
,1.248129800]

tp2=[0.000133200
,0.000154000
,0.000134800
,0.000155000
,0.000148000
,0.000193400
,0.000224200
,0.000304200
,0.0006702
,0.001295400
,0.010187200
,0.089685600
,0.827597000]

tp4=[0.000222000
,0.000211000
,0.000215200
,0.000225800
,0.000224000
,0.000233
,0.0002522
,0.000312400
,0.000521400
,0.000805000
,0.005600200
,0.049314200
,0.430565400]

tp6=[0.000328600
,0.000309800
,0.000325800
,0.0003268
,0.000338000
,0.000336600
,0.0003842
,0.000400200
,0.000589600
,0.000848200
,0.005264000
,0.042382000
,0.358389800]

tp8=[0.000341600
,0.000389200
,0.000337
,0.000387000
,0.000360000
,0.000332800
,0.000388000
,0.0004452
,0.000627800
,0.000864400
,0.0042204
,0.038452200
,0.323605600]

# %%
n=array([5
,10
,50
,100
,500
,1000
,5000
,10000
,50000
,100000
,1000000
,10000000
,100000000])

N=log(n)

# %%
plt.plot(N, tps)
plt.plot(N, tp2)
plt.plot(N, tp4)
plt.plot(N, tp6)
plt.plot(N, tp8)
plt.legend(["Serial", "2 threads", "4 threads", "6 threads", "8 threads"])
plt.ylabel("Execution time")
plt.xlabel("log(N)")
plt.title("Variation of total time \n with log of No. of sampling points")
plt.savefig("/Users/krishna/Desktop/trapezoid_log.png")
